# %%
import numpy as np
import pandas as pd

# %%
sub_in_tp = pd.read_csv('../../output/submission_xgb_area_valid_in_taipei.csv')
sub_out_tp = pd.read_csv('../../output/submission_xgb_area_valid_out_from_taipei.csv')
sub_all = pd.read_csv('../../output/submission_xgb_area_valid_both.csv')

# %%
sub_avg_in_tp = pd.concat([sub_all.set_index('building_id'), sub_in_tp.set_index('building_id')], axis=1, join='inner')

sub_avg_in_tp['avg'] = (sub_avg_in_tp.iloc[:, 0] + sub_avg_in_tp.iloc[:, 1]) / 2

# sub_avg_in_tp.head(10)

# %%
sub_avg_out_tp = pd.concat([sub_all.set_index('building_id'), sub_out_tp.set_index('building_id')], axis=1, join='inner')

sub_avg_out_tp['avg'] = (sub_avg_out_tp.iloc[:, 0] + sub_avg_out_tp.iloc[:, 1]) / 2

# sub_avg_out_tp.head(10)

# %%
sub_avg_split_by_tp = pd.concat([sub_avg_out_tp, sub_avg_in_tp])

# %%
submission = pd.DataFrame({
    "building_id": sub_avg_split_by_tp.index, 
    "total_price": sub_avg_split_by_tp.avg
})
submission.to_csv('../../output/submission_xgb_ensemble_split_by_taipei.csv', index=False)

# %%
submission
# Out:
#                        building_id   total_price
# building_id
# BTshNOJyKHnT2YIT  BTshNOJyKHnT2YIT  3.838146e+06
# dhdymr0lV8N5kZOT  dhdymr0lV8N5kZOT  1.001160e+07
# VEwyGGMcD56w5BOc  VEwyGGMcD56w5BOc  5.906221e+06
# wmUeMoJZfsqaSX9b  wmUeMoJZfsqaSX9b  1.020619e+06
# EtBjGAHmHCe9t7TZ  EtBjGAHmHCe9t7TZ  2.985344e+06
# hPNH34vmaZtvBtqc  hPNH34vmaZtvBtqc  1.224522e+07
# fxZSGX6aPAFKU8W4  fxZSGX6aPAFKU8W4  1.675328e+06
# ewr0Fx6ign87OwaV  ewr0Fx6ign87OwaV  3.887388e+06
# gHKurnEP4AowzsLg  gHKurnEP4AowzsLg  8.946151e+05
# PmLfTgY2FElLrTl0  PmLfTgY2FElLrTl0  5.453558e+06
# eM2NppIOwzW0o8iy  eM2NppIOwzW0o8iy  1.074537e+07
# dxxwNun97NH4WTrZ  dxxwNun97NH4WTrZ  2.549813e+06
# jykBfhh3vdeFUi3H  jykBfhh3vdeFUi3H  4.765094e+06
# D7jaFWHCzSqLBwdt  D7jaFWHCzSqLBwdt  9.849278e+05
# L10dBBdqGmemweSl  L10dBBdqGmemweSl  6.484718e+06
# OgB0AdiPKlElakKN  OgB0AdiPKlElakKN  1.132682e+06
# StiWNN1GQrpPBOYt  StiWNN1GQrpPBOYt  2.653358e+06
# gsCFcQHnOH3AKMcZ  gsCFcQHnOH3AKMcZ  3.439646e+06
# IbNsDXfsPwSuFpow  IbNsDXfsPwSuFpow  5.846489e+06
# EgAVWOVxD1Jy5YkE  EgAVWOVxD1Jy5YkE  1.303561e+06
# BrKghvR76XdbQPnx  BrKghvR76XdbQPnx  7.474684e+06
# a7fxkXTnUGWHUmKG  a7fxkXTnUGWHUmKG  2.172884e+07
# WgzXa170DfpzpURE  WgzXa170DfpzpURE  8.587110e+06
# JQgTtbVstqFZwEK1  JQgTtbVstqFZwEK1  4.439019e+05
# bCSDbEthlS3nSIor  bCSDbEthlS3nSIor  1.746785e+06
# Eg8c7ZRbL0gyAEAb  Eg8c7ZRbL0gyAEAb  1.743355e+06
# zsFOujpX1WUIkeMD  zsFOujpX1WUIkeMD  2.269078e+06
# jEvQfHD89c14eFJj  jEvQfHD89c14eFJj  8.667854e+06
# bU45TrRjtoRJpiOl  bU45TrRjtoRJpiOl  7.115012e+06
# YLKpsew5dW75vksT  YLKpsew5dW75vksT  6.636621e+06
# ...                            ...           ...
# SSC0yDhMGvWcf0EO  SSC0yDhMGvWcf0EO  2.094368e+07
# t1wvG6Sazb43VZS5  t1wvG6Sazb43VZS5  2.076386e+07
# BSaL2QbzBJLKlheE  BSaL2QbzBJLKlheE  1.456710e+07
# LCZKgRZluSkiDB5L  LCZKgRZluSkiDB5L  3.839374e+07
# M8zbOEkuATe6LHjK  M8zbOEkuATe6LHjK  2.941270e+07
# OiX8UnMlXaWwPDMq  OiX8UnMlXaWwPDMq  6.969243e+07
# aeOc85GleJ0fOy6R  aeOc85GleJ0fOy6R  3.361921e+06
# dIn8Kgv8ygqJNFHU  dIn8Kgv8ygqJNFHU  1.561956e+07
# ErxeROWYaEwK5Qlq  ErxeROWYaEwK5Qlq  1.408756e+07
# VWZy0whCjDjguKR8  VWZy0whCjDjguKR8  1.451733e+07
# C0gHoEeCqMWkFHQq  C0gHoEeCqMWkFHQq  5.454970e+06
# OHs5P1EfaQr7CuG5  OHs5P1EfaQr7CuG5  4.145532e+07
# Eik9BjECHArNPVxN  Eik9BjECHArNPVxN  3.097388e+07
# kAuR3PK8ZFJHgvNm  kAuR3PK8ZFJHgvNm  2.057652e+07
# VKc49zd4ScwOiixD  VKc49zd4ScwOiixD  1.466540e+06
# I2BIZd5XXhdO3Pk2  I2BIZd5XXhdO3Pk2  2.099183e+07
# z6CWOqM6aB6rPCH4  z6CWOqM6aB6rPCH4  1.092850e+07
# W9fJwElEPHyX8rJ3  W9fJwElEPHyX8rJ3  1.260190e+07
# pPHPGvOyGCjeaUCF  pPHPGvOyGCjeaUCF  8.582337e+06
# DxC9jH6h8RQuhNWK  DxC9jH6h8RQuhNWK  9.477617e+07
# jIXrSQCEM0v2CZzF  jIXrSQCEM0v2CZzF  6.323228e+07
# IYbjSgdKNzD2XDT8  IYbjSgdKNzD2XDT8  7.589613e+06
# jNIZa7d7xJReFLLq  jNIZa7d7xJReFLLq  3.919540e+06
# sOtYGCNq3pz9w7PI  sOtYGCNq3pz9w7PI  6.043597e+06
# Am6Wcg3TO64qvzd8  Am6Wcg3TO64qvzd8  3.206182e+07
# nVNYRuk2fRbtlV00  nVNYRuk2fRbtlV00  2.748337e+07
# lgZWdUKliWt2y5sM  lgZWdUKliWt2y5sM  1.158515e+07
# wTQmcqbN0OCuSF1t  wTQmcqbN0OCuSF1t  1.496499e+07
# WgsI1cBtzSfiWA1j  WgsI1cBtzSfiWA1j  1.646868e+07
# i0fgbPaQsDWs7Q87  i0fgbPaQsDWs7Q87  4.642308e+07
#
# [10000 rows x 2 columns]
